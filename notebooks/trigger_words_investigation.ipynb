# %%
# The objective of this file is to identify words suspect to appear on the wikipedia pages of 'bad actors' i.e. slave traders
# We will use the examples found from cross referencing with the wikipedia list of slave traders and the wikidata entries with
# the property of the 'legacies of a british slave trader'

# %%
from wikipedia_scrape import get_wiki_contents
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

import re
from collections import Counter

import pandas as pd

# %%
FILENAME = 'open-plaques-subjects-london.csv'
df = pd.read_csv(FILENAME)

df.dropna(subset = ['en_wikipedia_url'], inplace = True)

# %%
# Know bad slave traders from wikipedia list cross reference and wikidata attribute
know_names = ['James Brown','William Penn','John Marshall','Robert Milligan','Martin Van Buren','Benjamin Franklin', 
              'Quintin Hogg', 'William Ewart Gladstone', 'Elizabeth Barrett Browning']

content = ''

for name in know_names:
    url = df.loc[df['full_name'] == name, 'en_wikipedia_url'].iloc[0]
    n_content = get_wiki_contents(url)
    content = content + n_content.lower()
    print(len(n_content))
# Out:
# 76740
# 49631
# 52324
# 2084
# 67155
# 103151
# 4172
# 87404
# 28044

# %%
stop_words = set(stopwords.words('english')) 
word_tokens = word_tokenize(content) 
  
filtered_sentences = [w for w in word_tokens if not w in stop_words]

# %%
# Filter out the punctuation
nonPunct = re.compile('.*[A-Za-z].*')  # must contain a letter
filtered = [w for w in filtered_sentences if nonPunct.match(w)]
counts = Counter(filtered)

# %%
sorted(counts.items(), key=lambda item: item[1])[::-1]
# Out:
# [("'s", 841),
#  ('franklin', 459),
#  ('brown', 408),
#  ('gladstone', 283),
#  ('van', 256),
#  ('buren', 250),
#  ('penn', 241),
#  ('new', 207),
#  ('marshall', 204),
#  ('first', 186),
#  ('would', 161),
#  ('william', 153),
#  ('james', 147),
#  ('state', 145),
#  ('also', 145),
#  ('american', 139),
#  ('court', 136),
#  ('one', 128),
#  ('states', 121),
#  ('time', 116),
#  ('benjamin', 110),
#  ('government', 104),
#  ('united', 104),
#  ('john', 104),
#  ('later', 103),
#  ('party', 101),
#  ('became', 101),
#  ('london', 100),
#  ('president', 100),
#  ('two', 95),
#  ('pennsylvania', 94),
#  ('many', 94),
#  ('years', 94),
#  ('life', 93),
#  ('york', 92),
#  ('house', 91),
#  ('political', 88),
#  ('jackson', 88),
#  ('election', 79),
#  ('man', 78),
#  ('war', 76),
#  ('philadelphia', 75),
#  ('father', 75),
#  ('family', 72),
#  ('british', 71),
#  ('national', 71),
#  ('elizabeth', 69),
#  ('made', 69),
#  ('barrett', 68),
#  ('public', 68),
#  ('university', 66),
#  ('may', 66),
#  ('wrote', 65),
#  ('case', 63),
#  ('browning', 62),
#  ('england', 62),
#  ('great', 62),
#  ('law', 59),
#  ('death', 59),
#  ('including', 58),
#  ('supreme', 57),
#  ('second', 57),
#  ('support', 57),
#  ('year', 57),
#  ('early', 57),
#  ('office', 56),
#  ('george', 56),
#  ('act', 56),
#  ('lord', 56),
#  ('began', 56),
#  ('several', 56),
#  ('adams', 55),
#  ('people', 55),
#  ('king', 54),
#  ('richard', 53),
#  ('congress', 52),
#  ('son', 52),
#  ('federal', 52),
#  ('home', 52),
#  ('thomas', 51),
#  ('three', 51),
#  ('church', 49),
#  ('could', 49),
#  ('held', 48),
#  ('january', 48),
#  ('known', 48),
#  ('virginia', 47),
#  ('presidential', 47),
#  ('slavery', 46),
#  ('society', 46),
#  ('religious', 46),
#  ('though', 46),
#  ('secretary', 45),
#  ('america', 45),
#  ('children', 45),
#  ('died', 45),
#  ('work', 45),
#  ('justice', 44),
#  ('never', 44),
#  ('took', 44),
#  ('group', 44),
#  ('december', 44),
#  ('school', 43),
#  ('band', 43),
#  ('washington', 42),
#  ('named', 42),
#  ('members', 42),
#  ('continued', 42),
#  ('france', 41),
#  ('general', 41),
#  ('published', 41),
#  ('power', 41),
#  ('well', 41),
#  ('age', 41),
#  ('music', 41),
#  ('v.', 40),
#  ('convention', 40),
#  ('free', 40),
#  ('upon', 40),
#  ('february', 40),
#  ('april', 40),
#  ('south', 40),
#  ('like', 40),
#  ('famous', 40),
#  ('quakers', 39),
#  ('u.s.', 39),
#  ('former', 39),
#  ('young', 39),
#  ('english', 38),
#  ('mary', 38),
#  ('however', 38),
#  ('college', 38),
#  ('called', 38),
#  ('poems', 37),
#  ('quaker', 37),
#  ('believed', 37),
#  ('democratic', 37),
#  ('charles', 37),
#  ('following', 37),
#  ('married', 36),
#  ('last', 36),
#  ('served', 36),
#  ('led', 36),
#  ('b', 36),
#  ('world', 36),
#  ('trade', 35),
#  ('used', 35),
#  ('chief', 35),
#  ('r', 35),
#  ('slaves', 34),
#  ('without', 34),
#  ('history', 34),
#  ('said', 34),
#  ('among', 34),
#  ('part', 34),
#  ('included', 34),
#  ('october', 34),
#  ('song', 34),
#  ('released', 34),
#  ('helped', 34),
#  ('become', 34),
#  ('marriage', 34),
#  ('born', 34),
#  ('good', 34),
#  ('administration', 33),
#  ('god', 33),
#  ('city', 33),
#  ('although', 33),
#  ('much', 33),
#  ('often', 33),
#  ('cabinet', 32),
#  ('since', 32),
#  ('four', 32),
#  ('established', 32),
#  ('flames', 32),
#  ('georgia', 32),
#  ('minister', 31),
#  ('politics', 31),
#  ('works', 31),
#  ('end', 31),
#  ('july', 31),
#  ('times', 31),
#  ('returned', 31),
#  ('money', 31),
#  ('june', 31),
#  ('name', 31),
#  ('received', 31),
#  ('britain', 30),
#  ('bank', 30),
#  ('isbn', 30),
#  ('appointed', 30),
#  ('came', 30),
#  ('gave', 30),
#  ('way', 30),
#  ('film', 30),
#  ('march', 30),
#  ('local', 30),
#  ('another', 30),
#  ('hall', 30),
#  ('social', 30),
#  ('career', 30),
#  ('soul', 30),
#  ('opposed', 29),
#  ('liberal', 29),
#  ('ireland', 29),
#  ('constitution', 29),
#  ('issue', 29),
#  ('popular', 29),
#  ('live', 29),
#  ('century', 29),
#  ('opposition', 28),
#  ('nation', 28),
#  ('biography', 28),
#  ('boston', 28),
#  ('concert', 28),
#  ('personal', 28),
#  ('bill', 28),
#  ('member', 28),
#  ('governor', 27),
#  ('men', 27),
#  ('parliament', 27),
#  ('robert', 27),
#  ('press', 27),
#  ('old', 27),
#  ('wife', 27),
#  ('saw', 27),
#  ('pay', 27),
#  ('letters', 27),
#  ('day', 27),
#  ('sent', 27),
#  ('show', 27),
#  ('left', 27),
#  ('eventually', 27),
#  ('commons', 26),
#  ('jefferson', 26),
#  ('position', 26),
#  ('sir', 26),
#  ('refused', 26),
#  ('daughter', 26),
#  ('even', 26),
#  ('final', 26),
#  ('henry', 26),
#  ('make', 26),
#  ('along', 26),
#  ('met', 26),
#  ('library', 25),
#  ('strong', 25),
#  ('revolution', 25),
#  ('colonies', 25),
#  ('books', 25),
#  ('read', 25),
#  ('return', 25),
#  ('irish', 25),
#  ('use', 25),
#  ('country', 25),
#  ('influence', 25),
#  ('due', 25),
#  ('long', 25),
#  ('top', 25),
#  ('got', 25),
#  ('speech', 24),
#  ('senate', 24),
#  ('elected', 24),
#  ('oxford', 24),
#  ('west', 24),
#  ('poor', 24),
#  ('nomination', 24),
#  ('rather', 24),
#  ('statue', 24),
#  ('still', 24),
#  ('white', 24),
#  ('street', 24),
#  ('months', 24),
#  ('little', 24),
#  ('performed', 24),
#  ('autobiography', 24),
#  ('moved', 24),
#  ('late', 24),
#  ('brother', 24),
#  ('ed', 23),
#  ('writings', 23),
#  ('laws', 23),
#  ('september', 23),
#  ('policy', 23),
#  ('martin', 23),
#  ('rights', 23),
#  ('friend', 23),
#  ('august', 23),
#  ('land', 23),
#  ('decision', 23),
#  ('despite', 23),
#  ('right', 23),
#  ('come', 23),
#  ('near', 23),
#  ('black', 23),
#  ('success', 23),
#  ('term', 22),
#  ('chancellor', 22),
#  ('online', 22),
#  ('colonial', 22),
#  ('votes', 22),
#  ('education', 22),
#  ('went', 22),
#  ('see', 22),
#  ('instead', 22),
#  ('book', 22),
#  ('remained', 22),
#  ('vice', 22),
#  ('found', 22),
#  ('principle', 22),
#  ('back', 22),
#  ('say', 22),
#  ('joined', 22),
#  ('major', 22),
#  ('clay', 21),
#  ('treaty', 21),
#  ('important', 21),
#  ('rule', 21),
#  ('liberty', 21),
#  ('freedom', 21),
#  ('legal', 21),
#  ('campaign', 21),
#  ('civil', 21),
#  ('johnson', 21),
#  ('hynie', 21),
#  ('north', 21),
#  ('service', 21),
#  ('appeared', 21),
#  ('worked', 21),
#  ('written', 21),
#  ('tax', 21),
#  ('others', 21),
#  ('thought', 21),
#  ('peace', 21),
#  ('passed', 21),
#  ('followed', 21),
#  ('proposed', 21),
#  ('single', 21),
#  ('business', 21),
#  ('period', 21),
#  ('five', 21),
#  ('calhoun', 20),
#  ('whig', 20),
#  ('slave', 20),
#  ('help', 20),
#  ('letter', 20),
#  ('royal', 20),
#  ('relations', 20),
#  ('admiral', 20),
#  ('madison', 20),
#  ('supported', 20),
#  ('working', 20),
#  ('making', 20),
#  ('system', 20),
#  ('living', 20),
#  ('considered', 20),
#  ('independence', 20),
#  ("n't", 20),
#  ('original', 20),
#  ('augusta', 20),
#  ('carolina', 20),
#  ('records', 20),
#  ('record', 20),
#  ('ewart', 19),
#  ('constitutional', 19),
#  ('vote', 19),
#  ('foreign', 19),
#  ('judicial', 19),
#  ('pp', 19),
#  ('individual', 19),
#  ('religion', 19),
#  ('leading', 19),
#  ('put', 19),
#  ('honor', 19),
#  ('high', 19),
#  ('health', 19),
#  ('leader', 19),
#  ('reading', 19),
#  ('us', 19),
#  ('november', 19),
#  ('financial', 19),
#  ('around', 19),
#  ('third', 19),
#  ('take', 19),
#  ('center', 19),
#  ('get', 19),
#  ('hit', 19),
#  ('hogg', 18),
#  ('reform', 18),
#  ('question', 18),
#  ('conservative', 18),
#  ('papers', 18),
#  ('quickly', 18),
#  ('samuel', 18),
#  ('large', 18),
#  ('collection', 18),
#  ('county', 18),
#  ('newspaper', 18),
#  ('nothing', 18),
#  ('role', 18),
#  ('six', 18),
#  ('jersey', 18),
#  ('presidency', 18),
#  ('based', 18),
#  ('together', 18),
#  ('lost', 18),
#  ('company', 18),
#  ('issues', 18),
#  ('owned', 18),
#  ('go', 18),
#  ('claimed', 18),
#  ('spent', 18),
#  ('mother', 18),
#  ('noted', 18),
#  ('please', 18),
#  ('founded', 18),
#  ('hawarden', 17),
#  ('annexation', 17),
#  ('whigs', 17),
#  ('paul', 17),
#  ('duty', 17),
#  ('economic', 17),
#  ('affairs', 17),
#  ('plan', 17),
#  ('ever', 17),
#  ('french', 17),
#  ('christian', 17),
#  ('series', 17),
#  ('paper', 17),
#  ('order', 17),
#  ('decided', 17),
#  ('review', 17),
#  ('estate', 17),
#  ('attorney', 17),
#  ('various', 17),
#  ('private', 17),
#  ('memorial', 17),
#  ('crawford', 17),
#  ('failed', 17),
#  ('according', 17),
#  ('issued', 17),
#  ('throughout', 17),
#  ('child', 17),
#  ('chart', 17),
#  ('album', 17),
#  ('described', 16),
#  ('electrical', 16),
#  ('lightning', 16),
#  ('democrats', 16),
#  ('texas', 16),
#  ('raised', 16),
#  ('prime', 16),
#  ('edward', 16),
#  ('crisis', 16),
#  ('electoral', 16),
#  ('democratic-republican', 16),
#  ('opinion', 16),
#  ('andrew', 16),
#  ('indian', 16),
#  ('battle', 16),
#  ('ideas', 16),
#  ('crown', 16),
#  ('attended', 16),
#  ('place', 16),
#  ('domestic', 16),
#  ('thus', 16),
#  ('meeting', 16),
#  ('europe', 16),
#  ('writing', 16),
#  ('paris', 16),
#  ('call', 16),
#  ('prominent', 16),
#  ('david', 16),
#  ('especially', 16),
#  ('love', 16),
#  ('mr.', 16),
#  ('think', 16),
#  ('becoming', 16),
#  ('release', 16),
#  ('ii', 16),
#  ('recorded', 16),
#  ('byrd', 16),
#  ('singer', 16),
#  ('palmerston', 15),
#  ('peel', 15),
#  ('policies', 15),
#  ('chess', 15),
#  ('every', 15),
#  ('income', 15),
#  ('independent', 15),
#  ('emerged', 15),
#  ('justices', 15),
#  ('edition', 15),
#  ('founding', 15),
#  ('rest', 15),
#  ('debate', 15),
#  ('influential', 15),
#  ('half', 15),
#  ('assembly', 15),
#  ('colony', 15),
#  ('arts', 15),
#  ('visited', 15),
#  ('committee', 15),
#  ('leaders', 15),
#  ('away', 15),
#  ('appointment', 15),
#  ('interest', 15),
#  ('character', 15),
#  ('set', 15),
#  ('paid', 15),
#  ('special', 15),
#  ('volume', 15),
#  ('changed', 15),
#  ('reputation', 15),
#  ('influenced', 15),
#  ('peter', 14),
#  ('polk', 14),
#  ('kinderhook', 14),
#  ('declined', 14),
#  ('federalist', 14),
#  ('st', 14),
#  ('ford', 14),
#  ('argued', 14),
#  ('sought', 14),
#  ('moral', 14),
#  ('either', 14),
#  ('project', 14),
#  ('americans', 14),
#  ('smith', 14),
#  ('defeated', 14),
#  ('side', 14),
#  ('woman', 14),
#  ('eight', 14),
#  ('close', 14),
#  ('heard', 14),
#  ('practice', 14),
#  ('involved', 14),
#  ('let', 14),
#  ('park', 14),
#  ('clinton', 14),
#  ('earlier', 14),
#  ('magazine', 14),
#  ('empire', 14),
#  ('win', 14),
#  ('line', 14),
#  ('performance', 14),
#  ('signed', 14),
#  ('already', 14),
#  ('played', 14),
#  ('learned', 14),
#  ('stated', 14),
#  ('stone', 14),
#  ('fame', 14),
#  ('apollo', 14),
#  ('bobby', 14),
#  ('dance', 14),
#  ('opium', 13),
#  ('printer', 13),
#  ('budget', 13),
#  ('postmaster', 13),
#  ('duties', 13),
#  ('burr', 13),
#  ('correspondence', 13),
#  ('defeat', 13),
#  ('democratic-republicans', 13),
#  ('nominated', 13),
#  ('serve', 13),
#  ('courts', 13),
#  ('widely', 13),
#  ('internet', 13),
#  ('essays', 13),
#  ('opened', 13),
#  ('adopted', 13),
#  ('majority', 13),
#  ('parliamentary', 13),
#  ('southern', 13),
#  ('experiment', 13),
#  ('shall', 13),
#  ('fox', 13),
#  ('military', 13),
#  ('far', 13),
#  ('science', 13),
#  ('therefore', 13),
#  ('principles', 13),
#  ('supporters', 13),
#  ('able', 13),
#  ('control', 13),
#  ('find', 13),
#  ('arrested', 13),
#  ('using', 13),
#  ('river', 13),
#  ('felt', 13),
#  ('must', 13),
#  ('created', 13),
#  ('mind', 13),
#  ('required', 13),
#  ('documentary', 13),
#  ('historians', 13),
#  ('full', 13),
#  ('force', 13),
#  ('almost', 13),
#  ('soon', 13),
#  ('provided', 13),
#  ('developed', 13),
#  ('latter', 13),
#  ('version', 13),
#  ('collins', 13),
#  ('formed', 13),
#  ('town', 13),
#  ('lived', 13),
#  ('songs', 13),
#  ('feel', 13),
#  ('experiments', 12),
#  ('printed', 12),
#  ('common', 12),
#  ('gazette', 12),
#  ('scientific', 12),
#  ('electricity', 12),
#  ('contributed', 12),
#  ('seat', 12),
#  ('harrison', 12),
#  ('treasury', 12),
#  ('resigned', 12),
#  ('likely', 12),
#  ('archive', 12),
#  ('stands', 12),
#  ('rejected', 12),
#  ('proposal', 12),
#  ('favored', 12),
#  ('nature', 12),
#  ('denied', 12),
#  ('open', 12),
#  ('virtue', 12),
#  ('christ', 12),
#  ('parents', 12),
#  ('catholic', 12),
#  ('lands', 12),
#  ('maryland', 12),
#  ('friends', 12),
#  ('duke', 12),
#  ('references', 12),
#  ('citizens', 12),
#  ('holding', 12),
#  ('fire', 12),
#  ('enough', 12),
#  ('secret', 12),
#  ('response', 12),
#  ('judge', 12),
#  ('suit', 12),
#  ('ceremony', 12),
#  ('arrived', 12),
#  ('electric', 12),
#  ('intended', 12),
#  ('short', 12),
#  ('next', 12),
#  ('publication', 12),
#  ('candidate', 12),
#  ('produced', 12),
#  ('european', 12),
#  ('television', 12),
#  ('modern', 12),
#  ('form', 12),
#  ('featured', 12),
#  ('point', 12),
#  ('recordings', 12),
#  ('style', 12),
#  ('ten', 12),
#  ('albums', 12),
#  ('scott', 12),
#  ('musical', 12),
#  ('change', 12),
#  ('native', 12),
#  ('birth', 12),
#  ('jr.', 12),
#  ('small', 12),
#  ('list', 12),
#  ('rolling', 12),
#  ('class', 12),
#  ("'m", 12),
#  ('built', 12),
#  ('figure', 12),
#  ('funk', 12),
#  ('joseph', 12),
#  ('poetry', 11),
#  ('poet', 11),
#  ('taxation', 11),
#  ('disraeli', 11),
#  ('liberals', 11),
#  ('mp', 11),
#  ('exchequer', 11),
#  ('critical', 11),
#  ('enlightenment', 11),
#  ('measure', 11),
#  ('queen', 11),
#  ('abolition', 11),
#  ('tariff', 11),
#  ('passage', 11),
#  ('better', 11),
#  ('historian', 11),
#  ('ship', 11),
#  ('cherokee', 11),
#  ('faction', 11),
#  ('richmond', 11),
#  ('decisions', 11),
#  ('key', 11),
#  ('institute', 11),
#  ('philosophical', 11),
#  ('notes', 11),
#  ('de', 11),
#  ('hamilton', 11),
#  ('strike', 11),
#  ('dispute', 11),
#  ('revolutionary', 11),
#  ('hoped', 11),
#  ('charter', 11),
#  ('daniel', 11),
#  ('portrait', 11),
#  ('puritan', 11),
#  ('navy', 11),
#  ('split', 11),
#  ('dutch', 11),
#  ('retrieved', 11),
#  ('annual', 11),
#  ('historical', 11),
#  ('initially', 11),
#  ('post', 11),
#  ('tried', 11),
#  ('within', 11),
#  ('senator', 11),
#  ('movement', 11),
#  ('community', 11),
#  ('done', 11),
#  ('republican', 11),
#  ('create', 11),
#  ('present', 11),
#  ('actions', 11),
#  ('asked', 11),
#  ('property', 11),
#  ('trust', 11),
#  ('treatment', 11),
#  ('seven', 11),
#  ('kingdom', 11),
#  ('best', 11),
#  ('something', 11),
#  ('today', 11),
#  ('need', 11),
#  ('nearly', 11),
#  ('entered', 11),
#  ('stand', 11),
#  ('addition', 11),
#  ('across', 11),
#  ('popularity', 11),
#  ('different', 11),
#  ('give', 11),
#  ('confirmed', 11),
#  ('pop', 11),
#  ('number', 11),
#  ('ben', 11),
#  ('words', 11),
#  ('convinced', 11),
#  ('gained', 11),
#  ('prison', 11),
#  ('traveled', 11),
#  ('streets', 11),
#  ('greatest', 11),
#  ('perform', 11),
#  ('lead', 11),
#  ('poem', 10),
#  ('labour', 10),
#  ('mr', 10),
#  ('liberalism', 10),
#  ('liverpool', 10),
#  ('polytechnic', 10),
#  ('women', 10),
#  ('leigh', 10),
#  ('kite', 10),
#  ('folger', 10),
#  ('economy', 10),
#  ('banks', 10),
#  ('albany', 10),
#  ('sale', 10),
#  ('weeks', 10),
#  ('randolph', 10),
#  ('direct', 10),
#  ('affair', 10),
#  ('delegates', 10),
#  ('site', 10),
#  ('building', 10),
#  ('represented', 10),
#  ('lady', 10),
#  ('s.', 10),
#  ('hannah', 10),
#  ('declaration', 10),
#  ('always', 10),
#  ('elections', 10),
#  ('territory', 10),
#  ('conditions', 10),
#  ('hope', 10),
#  ('establish', 10),
#  ('conscience', 10),
#  ('subject', 10),
#  ('declared', 10),
#  ('meetings', 10),
#  ('theory', 10),
#  ('scholar', 10),
#  ('mission', 10),
#  ('union', 10),
#  ('delaware', 10),
#  ('province', 10),
#  ('links', 10),
#  ('research', 10),
#  ('official', 10),
#  ('honorary', 10),
#  ('lifetime', 10),
#  ('awards', 10),
#  ('jury', 10),
#  ('days', 10),
#  ('charges', 10),
#  ('resulted', 10),
#  ('presidents', 10),
#  ('equal', 10),
#  ('differences', 10),
#  ('strongly', 10),
#  ('violence', 10),
#  ('wanted', 10),
#  ('benefit', 10),
#  ('hand', 10),
#  ('told', 10),
#  ('lower', 10),
#  ('b.', 10),
#  ('uk', 10),
#  ('alongside', 10),
#  ('retained', 10),
#  ('legacy', 10),
#  ('brothers', 10),
#  ('attempt', 10),
#  ('wright', 10),
#  ('bring', 10),
#  ('decades', 10),
#  ('true', 10),
#  ('critics', 10),
#  ('meant', 10),
#  ('separate', 10),
#  ('performing', 10),
#  ('fred', 10),
#  ('shortly', 10),
#  ('fellow', 10),
#  ('1960s', 10),
#  ('blues', 10),
#  ('aurora', 9),
#  ('chapman', 9),
#  ('ministry', 9),
#  ('pain', 9),
#  ('glass', 9),
#  ('cause', 9),
#  ('deborah', 9),
#  ('pamphlet', 9),
#  ('josiah', 9),
#  ('canada', 9),
#  ('printing', 9),
#  ('drew', 9),
#  ('introduced', 9),
#  ('academy', 9),
#  ('abolitionist', 9),
#  ('panic', 9),
#  ('jamaica', 9),
#  ('sugar', 9),
#  ('milligan', 9),
#  ('g.', 9),
#  ('p.', 9),
#  ('collections', 9),
#  ('emancipation', 9),
#  ('population', 9),
#  ('statesman', 9),
#  ('funds', 9),
#  ('subsequent', 9),
#  ('proposals', 9),
#  ('conduct', 9),
#  ('ships', 9),
#  ('federalists', 9),
#  ('necessity', 9),
#  ('gibbons', 9),
#  ('executive', 9),
#  ('marbury', 9),
#  ('army', 9),
#  ('continental', 9),
#  ('vol', 9),
#  ('documents', 9),
#  ('fall', 9),
#  ('might', 9),
#  ('radical', 9),
#  ('proved', 9),
#  ('believe', 9),
#  ('elder', 9),
#  ('victory', 9),
#  ('face', 9),
#  ('finally', 9),
#  ('idea', 9),
#  ('studies', 9),
#  ('improve', 9),
#  ('husband', 9),
#  ('effect', 9),
#  ('given', 9),
#  ('run', 9),
#  ('educated', 9),
#  ('catholics', 9),
#  ('spirit', 9),
#  ('castle', 9),
#  ('means', 9),
#  ('politician', 9),
#  ('external', 9),
#  ('view', 9),
#  ('clear', 9),
#  ('holy', 9),
#  ('significant', 9),
#  ('organized', 9),
#  ('greater', 9),
#  ('delivered', 9),
#  ('notable', 9),
#  ('presented', 9),
#  ('council', 9),
#  ('claims', 9),
#  ('argument', 9),
#  ('look', 9),
#  ('charge', 9),
#  ('accused', 9),
#  ('couple', 9),
#  ('whether', 9),
#  ('opportunity', 9),
#  ('necessary', 9),
#  ('via', 9),
#  ('threatened', 9),
#  ('ticket', 9),
#  ('provide', 9),
#  ('front', 9),
#  ('person', 9),
#  ('conducted', 9),
#  ('police', 9),
#  ('goal', 9),
#  ('international', 9),
#  ('example', 9),
#  ('grounds', 9),
#  ('representatives', 9),
#  ('placed', 9),
#  ('club', 9),
#  ('observed', 9),
#  ('hammer', 9),
#  ('mc', 9),
#  ('standing', 9),
#  ('real', 9),
#  ('grand', 9),
#  ('longer', 9),
#  ('francis', 9),
#  ('ran', 9),
#  ('future', 9),
#  ('writers', 9),
#  ('problems', 9),
#  ('reason', 9),
#  ('audience', 9),
#  ('grew', 9),
#  ('garden', 9),
#  ('successful', 9),
#  ('wesley', 9),
#  ('michael', 9),
#  ('musicians', 9),
#  ('turn', 9),
#  ('prior', 9),
#  ('ended', 9),
#  ('immediate', 9),
#  ('belief', 9),
#  ('contract', 9),
#  ('result', 9),
#  ('label', 9),
#  ('studio', 9),
#  ('agreed', 9),
#  ('parties', 9),
#  ('keep', 9),
#  ('secure', 9),
#  ('game', 9),
#  ('canal', 9),
#  ('winning', 9),
#  ('shows', 9),
#  ('cited', 9),
#  ('charts', 9),
#  ('reached', 9),
#  ('machine', 9),
#  ('1970s', 9),
#  ('singles', 9),
#  ('sometimes', 9),
#  ('singing', 9),
#  ('attention', 9),
#  ('coming', 9),
#  ('gospel', 9),
#  ('referred', 9),
#  ('greek', 8),
#  ('premiership', 8),
#  ('lords', 8),
#  ('russell', 8),
#  ('reforms', 8),
#  ('scholarly', 8),
#  ...]

# %%
# Know bad slave traders from wikipedia list cross reference and wikidata attribute
know_names = ['James Brown','William Penn','John Marshall','Robert Milligan','Martin Van Buren','Benjamin Franklin', 
              'Quintin Hogg', 'William Ewart Gladstone']#, 'Elizabeth Barrett Browning']

all_freqs = []
for name in know_names:
    url = df.loc[df['full_name'] == name, 'en_wikipedia_url'].iloc[0]
    content = get_wiki_contents(url).lower()
    
    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(content) 

    filtered_sentences = [w for w in word_tokens if not w in stop_words] 

    # Filter out the punctuation
    nonPunct = re.compile('.*[A-Za-z].*')  # must contain a letter
    filtered = [w for w in filtered_sentences if nonPunct.match(w)]
    counts = Counter(filtered)
    
    freqs = [pair[0] for pair in sorted(counts.items(), key=lambda item: item[1])][::-1]
    all_freqs.append(freqs)
    print(freqs[:10])
# Out:
# ['brown', "'s", 'james', 'band', 'also', 'music', 'b', 'r', 'song', 'new']
# ['penn', "'s", 'william', 'pennsylvania', 'quaker', 'quakers', 'new', 'father', 'king', 'admiral']
# ['marshall', 'court', "'s", 'state', 'supreme', 'john', 'states', 'case', 'virginia', 'federal']
# ['milligan', 'docks', 'west', 'london', 'india', "'s", 'street', 'statue', 'also', 'george']
# ['van', 'buren', "'s", 'jackson', 'new', 'party', 'state', 'president', 'election', 'york']
# ['franklin', "'s", 'benjamin', 'american', 'first', 'philadelphia', 'pennsylvania', 'new', 'one', 'became']
# ['hogg', 'polytechnic', 'london', 'quintin', "'s", 'street', 'school', 'university', 'regent', 'oxford']
# ['gladstone', "'s", 'government', 'first', 'lord', 'one', 'william', 'would', 'house', 'liberal']

# %%
all_words = set([item for sublist in all_freqs for item in sublist])

inter_count = {}
for word in all_words:
    inter_count[word] = 0
    for freq in all_freqs:
        if word in freq:
            inter_count[word] += 1

# %%
print(sorted(inter_count.items(), key=lambda item: item[1])[::-1][:200])
# Out:
# [('called', 8), ('george', 8), ('day', 8), ('later', 8), ('two', 8), ('public', 8), ('links', 8), ('external', 8), ('death', 8), ('may', 8), ("'s", 8), ('also', 8), ('years', 8), ('prominent', 8), ('born', 7), ('known', 7), ('three', 7), ('member', 7), ('living', 7), ('richard', 7), ('find', 7), ('old', 7), ('near', 7), ('second', 7), ('james', 7), ('owned', 7), ('named', 7), ('political', 7), ('education', 7), ('father', 7), ('street', 7), ('daughter', 7), ('built', 7), ('early', 7), ('local', 7), ('wrote', 7), ('july', 7), ('press', 7), ('son', 7), ('lord', 7), ('life', 7), ('school', 7), ('first', 7), ('left', 7), ('charles', 7), ('married', 7), ('part', 7), ('served', 7), ('time', 7), ('references', 7), ('february', 7), ('following', 7), ('personal', 7), ('family', 7), ('still', 7), ('york', 7), ('national', 7), ('eventually', 7), ('due', 7), ('died', 7), ('around', 7), ('january', 7), ('year', 7), ('june', 7), ('william', 7), ('history', 7), ('university', 7), ('see', 7), ('many', 7), ('held', 7), ('never', 7), ('became', 7), ('group', 7), ('made', 7), ('london', 7), ('thomas', 7), ('tried', 6), ('use', 6), ('place', 6), ('england', 6), ('response', 6), ('white', 6), ('learned', 6), ('create', 6), ('supported', 6), ('little', 6), ('right', 6), ('seven', 6), ('council', 6), ('case', 6), ('moved', 6), ('together', 6), ('official', 6), ('make', 6), ('become', 6), ('actions', 6), ('law', 6), ('came', 6), ('british', 6), ('campaign', 6), ('eight', 6), ('children', 6), ('force', 6), ('decided', 6), ('century', 6), ('fellow', 6), ('others', 6), ('community', 6), ('list', 6), ('failed', 6), ('times', 6), ('free', 6), ('rather', 6), ('treatment', 6), ('paper', 6), ('college', 6), ('reading', 6), ('gave', 6), ('support', 6), ('since', 6), ('opened', 6), ('met', 6), ('come', 6), ('movement', 6), ('financial', 6), ('retained', 6), ('power', 6), ('take', 6), ('smith', 6), ('city', 6), ('close', 6), ('freedom', 6), ('remained', 6), ('civil', 6), ('march', 6), ('throughout', 6), ('established', 6), ('end', 6), ('historical', 6), ('men', 6), ('considered', 6), ('john', 6), ('sent', 6), ('age', 6), ('house', 6), ('refused', 6), ('sources', 6), ('authority', 6), ('lived', 6), ('away', 6), ('returned', 6), ('return', 6), ('received', 6), ('act', 6), ('famous', 6), ('began', 6), ('believed', 6), ('good', 6), ('slaves', 6), ('required', 6), ('lower', 6), ('notable', 6), ('liberty', 6), ('mother', 6), ('issued', 6), ('much', 6), ('like', 6), ('suffered', 6), ('neither', 6), ('showed', 6), ('office', 6), ('grounds', 6), ('members', 6), ('september', 6), ('without', 6), ('growing', 6), ('young', 6), ('led', 6), ('noted', 6), ('henry', 6), ('poor', 6), ('various', 6), ('point', 6), ('north', 6), ('reputation', 6), ('upon', 6), ('war', 6), ('another', 6), ('along', 6), ('continued', 6), ('becoming', 6), ('took', 6), ('appointed', 6), ('high', 6), ('state', 6), ('foundation', 6), ('already', 6), ('figure', 6), ('would', 6), ('whether', 6)]
